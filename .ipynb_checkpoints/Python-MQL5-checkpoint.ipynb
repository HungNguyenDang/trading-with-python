# %%
import MetaTrader5 as mt5
mt5.initialize()
from datetime import datetime

# %%
login = 73710625
password = 'OjZy-bC1'
server = 'MetaQuotes-Demo'

# %%
mt5.login(login,password,server)
# Out:
# True

# %%
# rates =  mt5.copy_rates_from("EURUSD",mt5.TIMEFRAME_M15,datetime.now(),100)
# rates
# Out:
# array([(1708642800, 1.08206, 1.08218, 1.08195, 1.08204,  207,  0, 0),
#        (1708643700, 1.08203, 1.08225, 1.08201, 1.08209,  126,  2, 0),
#        (1708644600, 1.08208, 1.08226, 1.08199, 1.0821 ,  194,  1, 0),
#        (1708645500, 1.08208, 1.08231, 1.08207, 1.0822 ,  203,  3, 0),
#        (1708646400, 1.08222, 1.08232, 1.08171, 1.08213,  156, 15, 0),
#        (1708647300, 1.08216, 1.08228, 1.08199, 1.08213,  196, 14, 0),
#        (1708648200, 1.08216, 1.0824 , 1.08199, 1.08213,  268, 29, 0),
#        (1708649100, 1.08213, 1.08226, 1.08168, 1.0821 ,  335, 29, 0),
#        (1708650000, 1.08215, 1.08256, 1.08215, 1.08252,  320,  1, 0),
#        (1708650900, 1.08252, 1.08256, 1.08244, 1.08252,  167,  2, 0),
#        (1708651800, 1.08251, 1.08259, 1.0825 , 1.08254,  162,  0, 0),
#        (1708652700, 1.08255, 1.08255, 1.08246, 1.08252,  214,  2, 0),
#        (1708653600, 1.08252, 1.08278, 1.0825 , 1.08272,  433,  4, 0),
# ...

# %%
ticker = "EURSUSD"
interval = mt5.TIMEFRAME_M10
from_date = datetime.now()
no_of_rows = 100

rates = mt5.copy_rates_from(ticker,interval,from_date,no_of_rows)
rates

# %%
# mt5.copy_rates_from('EURSUSD',mt5.TIMEFRAME_M10,datetime.now(),100)
